# %%
import numpy as np

# %%
x=np.array([[1.,2.,3.],[4.,5.,6.]])

# %%
x
# Out:
# array([[1., 2., 3.],
#        [4., 5., 6.]])

# %%
y=np.array([[5.,5.,5.],[4.,4.,4.]])

# %%
y
# Out:
# array([[5., 5., 5.],
#        [4., 4., 4.]])

# %%
x+y
# Out:
# array([[ 6.,  7.,  8.],
#        [ 8.,  9., 10.]])

# %%
y-x
# Out:
# array([[ 4.,  3.,  2.],
#        [ 0., -1., -2.]])

# %%
x*5
# Out:
# array([[ 5., 10., 15.],
#        [20., 25., 30.]])

# %%
x=np.array([[1.,2.,3.],[4.,5.,6.]])
x
# Out:
# array([[1., 2., 3.],
#        [4., 5., 6.]])

# %%
y=np.array([[6.,23.],[-1.,7.],[8.,9.]])
y
# Out:
# array([[ 6., 23.],
#        [-1.,  7.],
#        [ 8.,  9.]])

# %%
x.dot(y)#x*y
# Out:
# array([[ 28.,  64.],
#        [ 67., 181.]])

# %%
np.dot(x,y)
# Out:
# array([[ 28.,  64.],
#        [ 67., 181.]])

# %%
y.dot(x)
# Out:
# array([[ 98., 127., 156.],
#        [ 27.,  33.,  39.],
#        [ 44.,  61.,  78.]])

# %%
np.dot(y,x)
# Out:
# array([[ 98., 127., 156.],
#        [ 27.,  33.,  39.],
#        [ 44.,  61.,  78.]])

# %%
from numpy.linalg import inv
