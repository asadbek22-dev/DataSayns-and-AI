# %%
import numpy as np

# %%
arr1 = np.array([1,2,3,4,5,6], dtype=np.float64)#bu float64 malumotlar turiga ega massiv bo'ladi
arr1
# Out:
# array([1., 2., 3., 4., 5., 6.])

# %%
arr2 = np.array([1,2,3], dtype=np.int32)#bu int32 malumotlar turiga ega massivni beradi
arr2
# Out:
# array([1, 2, 3], dtype=int32)

# %%
arr1.dtype
# Out:
# dtype('float64')

# %%
arr2.dtype
# Out:
# dtype('int32')

# %%
arr = np.array([1,2,3,4])# int64
arr
# Out:
# array([1, 2, 3, 4])

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
float_arr = arr.astype(np.float64)#float64 ga o'girdik
float_arr.dtype
# Out:
# dtype('float64')

# %%
data=np.array([3.4,5.7,6.3,2.9])#float64
data.dtype
# Out:
# dtype('float64')

# %%
int_data = data.astype(np.int64)
int_data.dtype
# Out:
# dtype('int64')
