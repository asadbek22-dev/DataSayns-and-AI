# %%
import numpy as np

# %%
arr = np.random.randn(4)
arr
# Out:
# array([-1.49862294,  1.51193185, -0.4295977 ,  0.46960542])

# %%
sor = np.sort(arr)# Tartiblangan versiyasi
sor
# Out:
# array([-1.49862294, -0.4295977 ,  0.46960542,  1.51193185])

# %%
arr.sort()# tartiblaydi
arr
# Out:
# array([-1.49862294, -0.4295977 ,  0.46960542,  1.51193185])

# %%
reve = -np.sort(-arr)
reve
# Out:
# array([ 1.51193185,  0.46960542, -0.4295977 , -1.49862294])

# %%
arrt = np.random.randn(2,4)
arrt
# Out:
# array([[-0.08832333, -1.42710798,  0.29725226, -0.78677539],
#        [ 0.36306749,  0.29289158,  0.34140293, -0.36840494]])

# %%
#axis 0 qator
rov = np.sort(arrt,axis=0)
rov
# Out:
# array([[-0.08832333, -1.42710798,  0.29725226, -0.78677539],
#        [ 0.36306749,  0.29289158,  0.34140293, -0.36840494]])

# %%
#axis=1 ustun
col= np.sort(arrt,axis = 1)
col
# Out:
# array([[-1.42710798, -0.78677539, -0.08832333,  0.29725226],
#        [-0.36840494,  0.29289158,  0.34140293,  0.36306749]])
