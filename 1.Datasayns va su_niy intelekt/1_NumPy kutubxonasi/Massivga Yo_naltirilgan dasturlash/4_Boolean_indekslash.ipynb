# %%
import numpy as np

# %%
names = np.array(['Hasan','Husan','Mirazbek','Elyor','Hasan','Javohir','Elyor'])
names
# Out:
# array(['Hasan', 'Husan', 'Mirazbek', 'Elyor', 'Hasan', 'Javohir', 'Elyor'],
#       dtype='<U8')

# %%
data = np.random.randn(7,4)
data
# Out:
# array([[-1.85784894,  0.8344208 ,  0.12637677, -0.14011135],
#        [ 0.34860813, -0.07327629, -2.61451023,  0.73665974],
#        [-0.77952933,  1.29139822,  0.22699223, -1.58591722],
#        [ 0.22070467,  0.6851187 , -0.53785491,  1.63985969],
#        [-0.66709874,  0.72302508,  0.27096728, -1.48858321],
#        [-0.89232119, -0.66001083, -2.14320022, -0.30010698],
#        [-0.33203798, -0.66122057,  0.28812786,  0.78792727]])

# %%
names == 'Hasan'
# Out:
# array([ True, False, False, False,  True, False, False])

# %%
data[names == 'Hasan']#Hasanga tegishli barcha malimotlarni ajratib olish
# Out:
# array([[-1.85784894,  0.8344208 ,  0.12637677, -0.14011135],
#        [-0.66709874,  0.72302508,  0.27096728, -1.48858321]])

# %%
data[names == 'Elyor']
# Out:
# array([[ 0.22070467,  0.6851187 , -0.53785491,  1.63985969],
#        [-0.33203798, -0.66122057,  0.28812786,  0.78792727]])

# %%
data[names == 'Javohir']
# Out:
# array([[-0.89232119, -0.66001083, -2.14320022, -0.30010698]])

# %%
data[names == 'Hasan',2:]
# Out:
# array([[ 0.12637677, -0.14011135],
#        [ 0.27096728, -1.48858321]])

# %%
data[names != 'Javohir']#JAvohirdan boshqa barcha malumotni chiqaradi
# Out:
# array([[-1.85784894,  0.8344208 ,  0.12637677, -0.14011135],
#        [ 0.34860813, -0.07327629, -2.61451023,  0.73665974],
#        [-0.77952933,  1.29139822,  0.22699223, -1.58591722],
#        [ 0.22070467,  0.6851187 , -0.53785491,  1.63985969],
#        [-0.66709874,  0.72302508,  0.27096728, -1.48858321],
#        [-0.33203798, -0.66122057,  0.28812786,  0.78792727]])

# %%
data[~(names == 'Hasan')]
# Out:
# array([[ 0.34860813, -0.07327629, -2.61451023,  0.73665974],
#        [-0.77952933,  1.29139822,  0.22699223, -1.58591722],
#        [ 0.22070467,  0.6851187 , -0.53785491,  1.63985969],
#        [-0.89232119, -0.66001083, -2.14320022, -0.30010698],
#        [-0.33203798, -0.66122057,  0.28812786,  0.78792727]])

# %%
data[0:2]
# Out:
# array([[-1.85784894,  0.8344208 ,  0.12637677, -0.14011135],
#        [ 0.34860813, -0.07327629, -2.61451023,  0.73665974]])

# %%
print(names)
print(data)
# Out:
# ['Hasan' 'Husan' 'Mirazbek' 'Elyor' 'Hasan' 'Javohir' 'Elyor']
# [[-1.85784894  0.8344208   0.12637677 -0.14011135]
#  [ 0.34860813 -0.07327629 -2.61451023  0.73665974]
#  [-0.77952933  1.29139822  0.22699223 -1.58591722]
#  [ 0.22070467  0.6851187  -0.53785491  1.63985969]
#  [-0.66709874  0.72302508  0.27096728 -1.48858321]
#  [-0.89232119 -0.66001083 -2.14320022 -0.30010698]
#  [-0.33203798 -0.66122057  0.28812786  0.78792727]]

# %%
mask = (names == 'Hasan') | (names == 'Husan')# "|" or (yoki)
mask
# Out:
# array([ True,  True, False, False,  True, False, False])

# %%
data[mask]#Hasn va Husanlarga tegishli malumotlar
# Out:
# array([[-1.85784894,  0.8344208 ,  0.12637677, -0.14011135],
#        [ 0.34860813, -0.07327629, -2.61451023,  0.73665974],
#        [-0.66709874,  0.72302508,  0.27096728, -1.48858321]])

# %%
data
# Out:
# array([[-1.85784894,  0.8344208 ,  0.12637677, -0.14011135],
#        [ 0.34860813, -0.07327629, -2.61451023,  0.73665974],
#        [-0.77952933,  1.29139822,  0.22699223, -1.58591722],
#        [ 0.22070467,  0.6851187 , -0.53785491,  1.63985969],
#        [-0.66709874,  0.72302508,  0.27096728, -1.48858321],
#        [-0.89232119, -0.66001083, -2.14320022, -0.30010698],
#        [-0.33203798, -0.66122057,  0.28812786,  0.78792727]])

# %%
data[data<0] = 0
data
# Out:
# array([[0.        , 0.8344208 , 0.12637677, 0.        ],
#        [0.34860813, 0.        , 0.        , 0.73665974],
#        [0.        , 1.29139822, 0.22699223, 0.        ],
#        [0.22070467, 0.6851187 , 0.        , 1.63985969],
#        [0.        , 0.72302508, 0.27096728, 0.        ],
#        [0.        , 0.        , 0.        , 0.        ],
#        [0.        , 0.        , 0.28812786, 0.78792727]])
