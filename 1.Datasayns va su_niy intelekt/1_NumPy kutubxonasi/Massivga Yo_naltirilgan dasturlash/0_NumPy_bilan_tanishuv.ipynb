# %%
import numpy as np

# %%
my_list = list(range(100000))#normal
my_array = np.array(range(100000))#vekto'rlashgan

# %%
# %time for _ in range(10): [x*2 for x in my_list]#normal
# Out:
# CPU times: user 69.3 ms, sys: 19.6 ms, total: 88.9 ms
# Wall time: 90.9 ms

# %%
# %time for _ in range(10): my_array*2 #vektor
# Out:
# CPU times: user 1.26 ms, sys: 0 ns, total: 1.26 ms
# Wall time: 1.27 ms

# %%
90.9/1.27
# Out:
# 71.5748031496063
