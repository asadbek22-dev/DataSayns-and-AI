# %%
import pandas as pd
import numpy as np

# %%
# !wget https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/merc.csv
#fayl ochish
# Out:
# --2024-01-07 09:57:55--  https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/merc.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 728047 (711K) [text/plain]
# Saving to: ‘merc.csv.1’
#
# merc.csv.1          100%[===================>] 710.98K  --.-KB/s    in 0.05s
#
# 2024-01-07 09:57:55 (13.9 MB/s) - ‘merc.csv.1’ saved [728047/728047]

# %%
# !git clone https://github.com/anvarnarz/praktikum_datasets
#githabdagi barcha fayllarni ochish
# Out:
# fatal: destination path 'praktikum_datasets' already exists and is not an empty directory.

# %%
df=pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/merc.csv")
df.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1    S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2   SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3    G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4    G Class  2016  73948    Automatic     4000   Petrol  325  30.1
#
#    engineSize
# 0         1.8
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0

# %%
pd.read_excel("praktikum_datasets/uzbekistan.xlsx",index_col=0,names=['hudud','maydoni','aholisi'])
# Out:
#                                maydoni  aholisi
# hudud
# Andijon viloyati                  4200  1899000
# Buxoro viloyati                  39400  1384700
# Fargʻona viloyati                 6800  2597000
# Jizzax viloyati                  20500   910500
# Xorazm viloyati                   6300  1200000
# Namangan viloyati                 7900  1862000
# Navoiy viloyati                 110800   767500
# Qashqadaryo viloyati             28400  2029000
# Qoraqalpogʻiston Respublikasi   160000  1200000
# Samarqand viloyati               16400  2322000
# Sirdaryo viloyati                 5100   648100
# Surxondaryo viloyati             20800  1676000
# Toshkent viloyati                15300  4450000

# %%
pd.read_csv("praktikum_datasets/automobile_data.csv", sep=";", nrows=15)
# Out:
#    index,company,body-style,wheel-base,length,engine-type,num-of-cylinders,horsepower,average-mileage,price
# 0   0,alfa-romero,convertible,88.6,168.8,dohc,four...
# 1   1,alfa-romero,convertible,88.6,168.8,dohc,four...
# 2   2,alfa-romero,hatchback,94.5,171.2,ohcv,six,15...
# 3       3,audi,sedan,99.8,176.6,ohc,four,102,24,13950
# 4       4,audi,sedan,99.4,176.6,ohc,five,115,18,17450
# 5       5,audi,sedan,99.8,177.3,ohc,five,110,19,15250
# 6      6,audi,wagon,105.8,192.7,ohc,five,110,19,18920
# 7       9,bmw,sedan,101.2,176.8,ohc,four,101,23,16430
# 8      10,bmw,sedan,101.2,176.8,ohc,four,101,23,16925
# 9       11,bmw,sedan,101.2,176.8,ohc,six,121,21,20970
# 10        13,bmw,sedan,103.5,189,ohc,six,182,16,30760
# 11      14,bmw,sedan,103.5,193.8,ohc,six,182,16,41315
# 12          15,bmw,sedan,110,197,ohc,six,182,15,36880
# 13  16,chevrolet,hatchback,88.4,141.1,l,three,48,4...
# 14  17,chevrolet,hatchback,94.5,155.9,ohc,four,70,...

# %%
df=pd.read_excel("praktikum_datasets/uzbekistan.xlsx",index_col=0,names=['hudud','maydoni','aholisi'])
df
# Out:
#                                maydoni  aholisi
# hudud
# Andijon viloyati                  4200  1899000
# Buxoro viloyati                  39400  1384700
# Fargʻona viloyati                 6800  2597000
# Jizzax viloyati                  20500   910500
# Xorazm viloyati                   6300  1200000
# Namangan viloyati                 7900  1862000
# Navoiy viloyati                 110800   767500
# Qashqadaryo viloyati             28400  2029000
# Qoraqalpogʻiston Respublikasi   160000  1200000
# Samarqand viloyati               16400  2322000
# Sirdaryo viloyati                 5100   648100
# Surxondaryo viloyati             20800  1676000
# Toshkent viloyati                15300  4450000

# %%
df.to_csv("newuzb.csv")

# %%
obj= df.maydoni
obj
# Out:
# hudud
# Andijon viloyati                   4200
# Buxoro viloyati                   39400
# Fargʻona viloyati                  6800
# Jizzax viloyati                   20500
# Xorazm viloyati                    6300
# Namangan viloyati                  7900
# Navoiy viloyati                  110800
# Qashqadaryo viloyati              28400
# Qoraqalpogʻiston Respublikasi    160000
# Samarqand viloyati                16400
# Sirdaryo viloyati                  5100
# Surxondaryo viloyati              20800
# Toshkent viloyati                 15300
# Name: maydoni, dtype: int64

# %%
obj.to_csv("uzmaydon.csv")

# %%
pd.read_csv("uzmaydon.csv",index_col='hudud',squeeze=True)
# Out:
# <ipython-input-54-02a71c12e381>:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   pd.read_csv("uzmaydon.csv",index_col='hudud',squeeze=True)
# hudud
# Andijon viloyati                   4200
# Buxoro viloyati                   39400
# Fargʻona viloyati                  6800
# Jizzax viloyati                   20500
# Xorazm viloyati                    6300
# Namangan viloyati                  7900
# Navoiy viloyati                  110800
# Qashqadaryo viloyati              28400
# Qoraqalpogʻiston Respublikasi    160000
# Samarqand viloyati                16400
# Sirdaryo viloyati                  5100
# Surxondaryo viloyati              20800
# Toshkent viloyati                 15300
# Name: maydoni, dtype: int64

# %%
df2=pd.read_csv('praktikum_datasets/automobile_data.csv',sep=';',index_col=0)
df2
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
hd=pd.HDFStore("data.h5")

# %%
hd.put("uzdata",df)

# %%
hd.put("cardata",df2)

# %%
hd.keys()
# Out:
# ['/cardata', '/uzdata']

# %%
hd['cardata']
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
hd.close()

# %%
hd=pd.HDFStore("data.h5")

# %%
hd.close()
