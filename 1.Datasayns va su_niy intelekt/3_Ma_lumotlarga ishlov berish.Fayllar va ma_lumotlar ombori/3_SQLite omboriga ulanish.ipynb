# %%
import pandas as pd
import sqlite3 as sql
from pprint import pprint as print

# %%
# !wget https://www.sqlitetutorial.net/wp-content/uploads/2018/03/chinook.zip
# Out:
# --2025-03-07 10:09:36--  https://www.sqlitetutorial.net/wp-content/uploads/2018/03/chinook.zip
# Resolving www.sqlitetutorial.net (www.sqlitetutorial.net)... 104.21.30.141, 172.67.172.250, 2606:4700:3037::ac43:acfa, ...
# Connecting to www.sqlitetutorial.net (www.sqlitetutorial.net)|104.21.30.141|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 305596 (298K) [application/zip]
# Saving to: ‘chinook.zip’
#
# chinook.zip         100%[===================>] 298.43K  --.-KB/s    in 0.05s
#
# 2025-03-07 10:09:36 (5.78 MB/s) - ‘chinook.zip’ saved [305596/305596]

# %%
# !unzip chinook.zip
# Out:
# Archive:  chinook.zip
#   inflating: chinook.db

# %%
db=sql.connect("chinook.db")
cur=db.cursor()

# %%
cur.execute("SELECT name FROM sqlite_master WHERE type='table';")
cur.fetchall()

# %%
cur.execute("SELECT COUNT (*) FROM employees")
cur.fetchone()
# Out:
# (8,)

# %%
cur.execute("PRAGMA table_info(customers);")
cur.fetchall()
# Out:
# [(0, 'CustomerId', 'INTEGER', 1, None, 1),
#  (1, 'FirstName', 'NVARCHAR(40)', 1, None, 0),
#  (2, 'LastName', 'NVARCHAR(20)', 1, None, 0),
#  (3, 'Company', 'NVARCHAR(80)', 0, None, 0),
#  (4, 'Address', 'NVARCHAR(70)', 0, None, 0),
#  (5, 'City', 'NVARCHAR(40)', 0, None, 0),
#  (6, 'State', 'NVARCHAR(40)', 0, None, 0),
#  (7, 'Country', 'NVARCHAR(40)', 0, None, 0),
#  (8, 'PostalCode', 'NVARCHAR(10)', 0, None, 0),
#  (9, 'Phone', 'NVARCHAR(24)', 0, None, 0),
#  (10, 'Fax', 'NVARCHAR(24)', 0, None, 0),
#  (11, 'Email', 'NVARCHAR(60)', 1, None, 0),
#  (12, 'SupportRepId', 'INTEGER', 0, None, 0)]

# %%
cur.execute("SELECT * FROM customers")
mij=cur.fetchall()

# %%
df= pd.read_sql("SELECT * FROM customers LIMIT 20",db,index_col="CustomerId")
df
# Out:
#             FirstName     LastName  \
# CustomerId
# 1                Luís    Gonçalves
# 2              Leonie       Köhler
# 3            François     Tremblay
# 4               Bjørn       Hansen
# 5           František  Wichterlová
# 6              Helena         Holý
# 7              Astrid       Gruber
# 8                Daan      Peeters
# 9                Kara      Nielsen
# 10            Eduardo      Martins
# 11          Alexandre        Rocha
# 12            Roberto      Almeida
# 13           Fernanda        Ramos
# 14               Mark      Philips
# 15           Jennifer     Peterson
# 16              Frank       Harris
# 17               Jack        Smith
# 18           Michelle       Brooks
# 19                Tim        Goyer
# 20                Dan       Miller
#
#                                                      Company  \
# CustomerId
# 1           Embraer - Empresa Brasileira de Aeronáutica S.A.
# 2                                                       None
# ...

# %%
qu = "SELECT CustomerId,Firstname,LastName,Phone, Country FROM customers"
df = pd.read_sql(qu,db,index_col="CustomerId")
df.head()
# Out:
#             FirstName     LastName               Phone         Country
# CustomerId
# 1                Luís    Gonçalves  +55 (12) 3923-5555          Brazil
# 2              Leonie       Köhler    +49 0711 2842222         Germany
# 3            François     Tremblay   +1 (514) 721-4711          Canada
# 4               Bjørn       Hansen     +47 22 44 22 22          Norway
# 5           František  Wichterlová    +420 2 4172 5555  Czech Republic

# %%
qu = "SELECT CustomerId,Firstname,LastName,Phone, Country FROM customers ORDER BY Country"
df = pd.read_sql(qu,db,index_col="CustomerId")
df
# Out:
#             FirstName      LastName                Phone         Country
# CustomerId
# 56              Diego     Gutiérrez  +54 (0)11 4311 4333       Argentina
# 55               Mark        Taylor   +61 (02) 9332 3633       Australia
# 7              Astrid        Gruber       +43 01 5134505         Austria
# 8                Daan       Peeters     +32 02 219 03 03         Belgium
# 1                Luís     Gonçalves   +55 (12) 3923-5555          Brazil
# 10            Eduardo       Martins   +55 (11) 3033-5446          Brazil
# 11          Alexandre         Rocha   +55 (11) 3055-3278          Brazil
# 12            Roberto       Almeida   +55 (21) 2271-7000          Brazil
# 13           Fernanda         Ramos   +55 (61) 3363-5547          Brazil
# 3            François      Tremblay    +1 (514) 721-4711          Canada
# 14               Mark       Philips    +1 (780) 434-4554          Canada
# 15           Jennifer      Peterson    +1 (604) 688-2255          Canada
# ...

# %%
qw="SELECT DISTINCT Country FROM customers"
cur.execute(qw)
cur.fetchall()
# Out:
# [('Brazil',),
#  ('Germany',),
#  ('Canada',),
#  ('Norway',),
#  ('Czech Republic',),
#  ('Austria',),
#  ('Belgium',),
#  ('Denmark',),
#  ('USA',),
#  ('Portugal',),
#  ('France',),
#  ('Finland',),
#  ('Hungary',),
#  ('Ireland',),
#  ('Italy',),
#  ('Netherlands',),
#  ('Poland',),
#  ('Spain',),
#  ('Sweden',),
#  ('United Kingdom',),
#  ('Australia',),
#  ('Argentina',),
#  ('Chile',),
#  ('India',)]

# %%
pd.read_sql(qw,db)
# Out:
#            Country
# 0           Brazil
# 1          Germany
# 2           Canada
# 3           Norway
# 4   Czech Republic
# 5          Austria
# 6          Belgium
# 7          Denmark
# 8              USA
# 9         Portugal
# 10          France
# 11         Finland
# 12         Hungary
# 13         Ireland
# 14           Italy
# 15     Netherlands
# 16          Poland
# 17           Spain
# 18          Sweden
# 19  United Kingdom
# 20       Australia
# 21       Argentina
# 22           Chile
# 23           India

# %%
qu='SELECT * FROM customers WHERE country="USA"AND State="NY"  ORDER BY Country'
pd.read_sql(qu,db)
# Out:
#    CustomerId FirstName LastName Company       Address      City State  \
# 0          18  Michelle   Brooks    None  627 Broadway  New York    NY
#
#   Country  PostalCode              Phone                Fax  \
# 0     USA  10012-2612  +1 (212) 221-3546  +1 (212) 221-4679
#
#                Email  SupportRepId
# 0  michelleb@aol.com             3

# %%
db.close()
