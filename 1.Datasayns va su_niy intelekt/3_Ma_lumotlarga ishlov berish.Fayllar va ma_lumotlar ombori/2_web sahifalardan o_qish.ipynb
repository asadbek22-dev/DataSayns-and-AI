# %%
import pandas as pd
import numpy as np

# %%
to=pd.read_html('https://en.wikipedia.org/wiki/Tashkent')

# %%
len(to)
# Out:
# 19

# %%
to[6]
# Out:
#                                                     0  \
# 0   YearPop.±% p.a.1897 155,673— 1959 911,930+2.89...
# 1                                                Year
# 2                                                1897
# 3                                                1959
# 4                                                1970
# 5                                                1979
# 6                                                1983
# 7                                                1989
# 8                                                1991
# 9                                                1995
# 10                                               2000
# 11                                               2001
# 12                                               2002
# 13                                               2003
# 14                                               2004
# 15                                               2005
# ...

# %% [markdown]
# # Json farmatidagi fayllarni o'qish

# %%
pd.read_json("sample_data/anscombe.json")
# Out:
#    Series   X      Y
# 0       I  10   8.04
# 1       I   8   6.95
# 2       I  13   7.58
# 3       I   9   8.81
# 4       I  11   8.33
# 5       I  14   9.96
# 6       I   6   7.24
# 7       I   4   4.26
# 8       I  12  10.84
# 9       I   7   4.81
# 10      I   5   5.68
# 11     II  10   9.14
# 12     II   8   8.14
# 13     II  13   8.74
# 14     II   9   8.77
# 15     II  11   9.26
# 16     II  14   8.10
# 17     II   6   6.13
# 18     II   4   3.10
# 19     II  12   9.13
# 20     II   7   7.26
# 21     II   5   4.74
# 22    III  10   7.46
# 23    III   8   6.77
# 24    III  13  12.74
# 25    III   9   7.11
# 26    III  11   7.81
# 27    III  14   8.84
# 28    III   6   6.08
# 29    III   4   5.39
# 30    III  12   8.15
# 31    III   7   6.42
# 32    III   5   5.73
# 33     IV   8   6.58
# 34     IV   8   5.76
# 35     IV   8   7.71
# 36     IV   8   8.84
# 37     IV   8   8.47
# 38     IV   8   7.04
# 39     IV   8   5.25
# 40     IV  19  12.50
# 41     IV   8   5.56
# ...

# %%
import requests
r=requests.get("https://openlibrary.org/subjects/python.json?published_in=2010-2024")
r.status_code
# Out:
# 200

# %%
da=pd.DataFrame(r.json()['works'])
# Out:
#                    key                        title  edition_count   cover_id  \
# 0    /works/OL2784125W              Learning Python             20  1312568.0
# 1    /works/OL2784127W                       Python             13   988215.0
# 2    /works/OL2784126W           Programming Python             10   805644.0
# 3   /works/OL17795703W    Python for bioinformatics             10  8078288.0
# 4   /works/OL16976951W                 Think Python             10  7363360.0
# 5   /works/OL15664278W            Head First Python              9  6681113.0
# 6    /works/OL6045694W         Python in a Nutshell              8   389166.0
# 7   /works/OL16223034W                  Think Stats              8  6956191.0
# 8   /works/OL23330617W  Making music with computers              7        NaN
# 9   /works/OL17422847W     Python For Data Analysis              7  7548132.0
# 10  /works/OL14873289W              Python Cookbook              7   388536.0
# ...
