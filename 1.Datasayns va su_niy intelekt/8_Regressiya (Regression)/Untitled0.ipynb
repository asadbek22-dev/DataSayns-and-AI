# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/housing_data_08-02-2021.csv',index_col=0)
df.head(10)
# Out:
#                                                          district  rooms size  \
# location
# город Ташкент, Юнусабадский район, Юнусабад 8-й...   Юнусабадский      3   57
# город Ташкент, Яккасарайский район, 1-й тупик Ш...  Яккасарайский      2   52
# город Ташкент, Чиланзарский район, Чиланзар 2-й...   Чиланзарский      2   42
# город Ташкент, Чиланзарский район, Чиланзар 9-й...   Чиланзарский      3   65
# город Ташкент, Чиланзарский район, площадь Актепа    Чиланзарский      3   70
# город Ташкент, Чиланзарский район, Чиланзар 6-й...   Чиланзарский      1   28
# город Ташкент, Чиланзарский район, Чиланзар-16       Чиланзарский      1   30
# город Ташкент, Яккасарайский район, Саламатина      Яккасарайский      2   32
# город Ташкент, Учтепинский район, Чиланзар-21         Учтепинский      2   51
# город Ташкент, Чиланзарский район, Чиланзар-8        Чиланзарский      1   30
#
#                                                     level  max_levels  price
# location
# ...

# %%
print(df.columns)
# Out:
# Index(['district', 'rooms', 'size', 'level', 'max_levels', 'price'], dtype='object')

# %%
df = df.drop(columns=['location'], errors='ignore')

# %%
print(df.index)
# Out:
# Index(['город Ташкент, Юнусабадский район, Юнусабад 8-й квартал',
#        'город Ташкент, Яккасарайский район, 1-й тупик Шота Руставели',
#        'город Ташкент, Чиланзарский район, Чиланзар 2-й квартал',
#        'город Ташкент, Чиланзарский район, Чиланзар 9-й квартал',
#        'город Ташкент, Чиланзарский район, площадь Актепа',
#        'город Ташкент, Чиланзарский район, Чиланзар 6-й квартал',
#        'город Ташкент, Чиланзарский район, Чиланзар-16',
#        'город Ташкент, Яккасарайский район, Саламатина',
#        'город Ташкент, Учтепинский район, Чиланзар-21',
#        'город Ташкент, Чиланзарский район, Чиланзар-8',
#        ...
#        'город Ташкент, Мирзо-Улугбекский район, Ц-1 кафе Bibigon',
#        'город Ташкент, Яшнободский район, Базар Кадышева',
#        'город Ташкент, Мирабадский район, Айбека (пр-т Косманавтов) ',
#        'город Ташкент, Шайхантахурский район, Ибн Сина-2',
#        'город Ташкент, Шайхантахурский район, Алишера Навои',
# ...

# %%
df = df.reset_index()

# %%
housing=df
housing
# Out:
#                district  rooms size  level  max_levels  price
# 0          Юнусабадский      3   57      4           4  52000
# 1         Яккасарайский      2   52      4           5  56000
# 2          Чиланзарский      2   42      4           4  37000
# 3          Чиланзарский      3   65      1           4  49500
# 4          Чиланзарский      3   70      3           5  55000
# ...                 ...    ...  ...    ...         ...    ...
# 7560        Яшнободский      1   38      5           5  24500
# 7561        Яшнободский      2   49      1           4  32000
# 7562    Шайхантахурский      2   64      3           9  40000
# 7563  Мирзо-Улугбекский      1   18      1           4  11000
# 7564       Чиланзарский      1   30      2           4  22914
#
# [7565 rows x 6 columns]

# %%
df['district'].value_counts()
# Out:
# district
# Чиланзарский         1641
# Мирзо-Улугбекский    1382
# Юнусабадский          883
# Учтепинский           880
# Мирабадский           773
# Яккасарайский         658
# Яшнободский           484
# Шайхантахурский       396
# Олмазорский           269
# Сергелийский          175
# Янгихаётский           16
# Бектемирский            8
# Name: count, dtype: int64

# %%
housing = df[df.district=='Чиланзарский']
housing.head()
# Out:
#        district  rooms size  level  max_levels  price
# 2  Чиланзарский      2   42      4           4  37000
# 3  Чиланзарский      3   65      1           4  49500
# 4  Чиланзарский      3   70      3           5  55000
# 5  Чиланзарский      1   28      1           4  25500
# 6  Чиланзарский      1   30      2           4  21200

# %%
x = housing['size']
x
# Out:
# 2       42
# 3       65
# 4       70
# 5       28
# 6       30
#         ..
# 7504    70
# 7522    20
# 7533    32
# 7545    70
# 7564    30
# Name: size, Length: 1641, dtype: object

# %%
y = housing['price']
y
# Out:
# 2       37000
# 3       49500
# 4       55000
# 5       25500
# 6       21200
#         ...
# 7504    48000
# 7522    18500
# 7533    28000
# 7545    49800
# 7564    22914
# Name: price, Length: 1641, dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=housing, x='size', y='price')
plt.show()

# %%
housing.shape
# Out:
# (1641, 6)

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1641 entries, 2 to 7564
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   district    1641 non-null   object
#  1   rooms       1641 non-null   int64
#  2   size        1641 non-null   object
#  3   level       1641 non-null   int64
#  4   max_levels  1641 non-null   int64
#  5   price       1641 non-null   object
# dtypes: int64(3), object(3)
# memory usage: 89.7+ KB

# %%
housing['size'] = pd.to_numeric(housing['size'], errors='coerce')
# Out:
# <ipython-input-51-4ac84dbbe2bf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing['size'] = pd.to_numeric(housing['size'], errors='coerce')

# %%
housing['price'] = pd.to_numeric(housing['price'], errors='coerce')
# Out:
# <ipython-input-54-2817dc6965ea>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing['price'] = pd.to_numeric(housing['price'], errors='coerce')

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1641 entries, 2 to 7564
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   district    1641 non-null   object
#  1   rooms       1641 non-null   int64
#  2   size        1641 non-null   int64
#  3   level       1641 non-null   int64
#  4   max_levels  1641 non-null   int64
#  5   price       1641 non-null   int64
# dtypes: int64(5), object(1)
# memory usage: 89.7+ KB

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=housing, x='size', y='price')
plt.show()

# %%
housing
# Out:
#           district  rooms  size  level  max_levels    price
# 2     Чиланзарский      2    42      4           4  37000.0
# 3     Чиланзарский      3    65      1           4  49500.0
# 4     Чиланзарский      3    70      3           5  55000.0
# 5     Чиланзарский      1    28      1           4  25500.0
# 6     Чиланзарский      1    30      2           4  21200.0
# ...            ...    ...   ...    ...         ...      ...
# 7504  Чиланзарский      3    70      3           4  48000.0
# 7522  Чиланзарский      1    20      5           5  18500.0
# 7533  Чиланзарский      1    32      3           4  28000.0
# 7545  Чиланзарский      3    70      1           4  49800.0
# 7564  Чиланзарский      1    30      2           4  22914.0
#
# [1641 rows x 6 columns]

# %%
housing['size'] = housing['size'].astype('int64')
# Out:
# <ipython-input-59-cfe3ac695541>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing['size'] = housing['size'].astype('int64')

# %%
housing['price'] = housing['price'].fillna(0)
# Out:
# <ipython-input-62-70fee8569545>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing['price'] = housing['price'].fillna(0)

# %%
housing['price'] = housing['price'].astype('int64')
# Out:
# <ipython-input-63-2232867fb1fa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing['price'] = housing['price'].astype('int64')

# %%
housing
# Out:
#           district  rooms  size  level  max_levels  price
# 2     Чиланзарский      2    42      4           4  37000
# 3     Чиланзарский      3    65      1           4  49500
# 4     Чиланзарский      3    70      3           5  55000
# 5     Чиланзарский      1    28      1           4  25500
# 6     Чиланзарский      1    30      2           4  21200
# ...            ...    ...   ...    ...         ...    ...
# 7504  Чиланзарский      3    70      3           4  48000
# 7522  Чиланзарский      1    20      5           5  18500
# 7533  Чиланзарский      1    32      3           4  28000
# 7545  Чиланзарский      3    70      1           4  49800
# 7564  Чиланзарский      1    30      2           4  22914
#
# [1641 rows x 6 columns]

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=housing, x='size', y='price')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.regplot(data=housing, x='size', y='price', line_kws={"color": "red"})
plt.show()

# %%
housing = housing.dropna(subset=['size', 'price'])

# %%
X = housing['size']
y = pd.to_numeric(df['price'], errors='coerce')

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1641 entries, 2 to 7564
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   district    1641 non-null   object
#  1   rooms       1641 non-null   int64
#  2   size        1641 non-null   int64
#  3   level       1641 non-null   int64
#  4   max_levels  1641 non-null   int64
#  5   price       1641 non-null   int64
# dtypes: int64(5), object(1)
# memory usage: 154.3+ KB

# %%
X=housing['size'].mean()
Y=housing['price'].mean()

# %%
print(housing.isna().sum())
# Out:
# district      0
# rooms         0
# size          0
# level         0
# max_levels    0
# price         0
# dtype: int64

# %%
numerator = sum((x - X) * (y - Y))
denominator = sum((x - X) ** 2)

theta_1 = numerator / denominator
theta_1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-94-5d61e01106c8> in <cell line: 1>()
# ----> 1 numerator = sum((x - X) )
#       2 denominator = sum((x - X) ** 2)
#       3
#       4 theta_1 = numerator / denominator
#       5 theta_1
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
