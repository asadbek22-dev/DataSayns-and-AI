# %% [markdown]
# #Malumotlarga ishlov berish
# #Multi indekslash

# %%
import pandas as pd
import numpy as np

# %%
data = pd.Series(np.random.randn(9), index=['a','a','a','b','b','c','c','d','d'])#odatiy indeksli series
data.index
data
# Out:
# a   -0.773648
# a   -0.934409
# a    1.431044
# b    0.115199
# b    0.258322
# c   -1.635972
# c    0.191760
# d    0.233022
# d   -0.032984
# dtype: float64

# %%
data1 = pd.Series(np.random.randn(9),index=[['a', 'a', 'a', 'b', 'b', 'c', 'c', 'd', 'd'],[1,2,3,1,3,1,2,2,3]])#irarxik indeksli serisni qaytaradi
data1.index
# Out:
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('a', 3),
#             ('b', 1),
#             ('b', 3),
#             ('c', 1),
#             ('c', 2),
#             ('d', 2),
#             ('d', 3)],
#            )

# %%
data1
# Out:
# a  1    0.302440
#    2    1.391249
#    3   -0.078498
# b  1    0.685017
#    3   -0.581308
# c  1    0.197091
#    2   -0.642018
# d  2    0.297013
#    3   -0.848370
# dtype: float64

# %%
data1['a']#sabsetlaribilan ajratib oladi
# Out:
# 1    0.302440
# 2    1.391249
# 3   -0.078498
# dtype: float64

# %%
data1.loc[:,2]
# Out:
# a    1.391249
# c   -0.642018
# d    0.297013
# dtype: float64

# %%
data1.loc[['b','d']]
# Out:
# b  1    0.685017
#    3   -0.581308
# d  2    0.297013
#    3   -0.848370
# dtype: float64

# %%
data1
# Out:
# a  1    0.302440
#    2    1.391249
#    3   -0.078498
# b  1    0.685017
#    3   -0.581308
# c  1    0.197091
#    2   -0.642018
# d  2    0.297013
#    3   -0.848370
# dtype: float64

# %%
data1.unstack()#sochilgan ser df ko'rinishda qaytaradi
# Out:
#           1         2         3
# a  0.302440  1.391249 -0.078498
# b  0.685017       NaN -0.581308
# c  0.197091 -0.642018       NaN
# d       NaN  0.297013 -0.848370

# %%
data1.unstack().stack()
# Out:
# a  1    0.302440
#    2    1.391249
#    3   -0.078498
# b  1    0.685017
#    3   -0.581308
# c  1    0.197091
#    2   -0.642018
# d  2    0.297013
#    3   -0.848370
# dtype: float64

# %%
# !git clone https://github.com/MansurCompAI/Practicum_Datasets.git
# Out:
# Cloning into 'Practicum_Datasets'...
# remote: Enumerating objects: 60, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 60 (delta 17), reused 16 (delta 1), pack-reused 0
# Receiving objects: 100% (60/60), 20.24 MiB | 13.32 MiB/s, done.
# Resolving deltas: 100% (17/17), done.

# %%
df = pd.read_csv("/content/Practicum_Datasets/world_cities_air_water_quality.csv")
df
# Out:
#                   City                 "Region"                    "Country"  \
# 0        New York City               "New York"   "United States of America"
# 1     Washington, D.C.   "District of Columbia"   "United States of America"
# 2        San Francisco             "California"   "United States of America"
# 3               Berlin                       ""                    "Germany"
# 4          Los Angeles             "California"   "United States of America"
# ...                ...                      ...                          ...
# 3958             Yanbu        "Medina Province"               "Saudi Arabia"
# 3959           Cordoba              "Andalusia"                      "Spain"
# 3960               Vic              "Catalonia"                      "Spain"
# 3961           Segovia       "Castile and Leon"                      "Spain"
# 3962       Zamora city       "Castile and Leon"                      "Spain"
#
#        "AirQuality"   "WaterPollution"
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3963 entries, 0 to 3962
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   City               3963 non-null   object
#  1    "Region"          3963 non-null   object
#  2    "Country"         3963 non-null   object
#  3    "AirQuality"      3963 non-null   float64
#  4    "WaterPollution"  3963 non-null   float64
# dtypes: float64(2), object(3)
# memory usage: 154.9+ KB

# %%
clum = ['City',	'Region','Country','AirQuality','WaterPollution']
df.columns= clum
df
# Out:
#                   City                   Region                      Country  \
# 0        New York City               "New York"   "United States of America"
# 1     Washington, D.C.   "District of Columbia"   "United States of America"
# 2        San Francisco             "California"   "United States of America"
# 3               Berlin                       ""                    "Germany"
# 4          Los Angeles             "California"   "United States of America"
# ...                ...                      ...                          ...
# 3958             Yanbu        "Medina Province"               "Saudi Arabia"
# 3959           Cordoba              "Andalusia"                      "Spain"
# 3960               Vic              "Catalonia"                      "Spain"
# 3961           Segovia       "Castile and Leon"                      "Spain"
# 3962       Zamora city       "Castile and Leon"                      "Spain"
#
#       AirQuality  WaterPollution
# ...

# %%
df['Region'] = df['Region'].map(lambda x: x.replace('"',""))
df
# Out:
#                   City                 Region                      Country  \
# 0        New York City               New York   "United States of America"
# 1     Washington, D.C.   District of Columbia   "United States of America"
# 2        San Francisco             California   "United States of America"
# 3               Berlin                                           "Germany"
# 4          Los Angeles             California   "United States of America"
# ...                ...                    ...                          ...
# 3958             Yanbu        Medina Province               "Saudi Arabia"
# 3959           Cordoba              Andalusia                      "Spain"
# 3960               Vic              Catalonia                      "Spain"
# 3961           Segovia       Castile and Leon                      "Spain"
# 3962       Zamora city       Castile and Leon                      "Spain"
#
#       AirQuality  WaterPollution
# 0      46.816038       49.504950
# ...

# %%
df['Country'] = df['Country'].map(lambda x: x.replace('"',""))
df
# Out:
#                   City                 Region                    Country  \
# 0        New York City               New York   United States of America
# 1     Washington, D.C.   District of Columbia   United States of America
# 2        San Francisco             California   United States of America
# 3               Berlin                                           Germany
# 4          Los Angeles             California   United States of America
# ...                ...                    ...                        ...
# 3958             Yanbu        Medina Province               Saudi Arabia
# 3959           Cordoba              Andalusia                      Spain
# 3960               Vic              Catalonia                      Spain
# 3961           Segovia       Castile and Leon                      Spain
# 3962       Zamora city       Castile and Leon                      Spain
#
#       AirQuality  WaterPollution
# 0      46.816038       49.504950
# ...

# %%
df.to_csv("Updatae_dataset.csv",index=False)

# %%
df[df['Country'] == 'Germany']
# Out:
# Empty DataFrame
# Columns: [City, Region, Country, AirQuality, WaterPollution]
# Index: []

# %%
df['Country'][2]
# Out:
# ' United States of America'

# %%
df['Country'] = df['Country'].map(lambda x: x.strip())
df
# Out:
#                   City                 Region                   Country  \
# 0        New York City               New York  United States of America
# 1     Washington, D.C.   District of Columbia  United States of America
# 2        San Francisco             California  United States of America
# 3               Berlin                                          Germany
# 4          Los Angeles             California  United States of America
# ...                ...                    ...                       ...
# 3958             Yanbu        Medina Province              Saudi Arabia
# 3959           Cordoba              Andalusia                     Spain
# 3960               Vic              Catalonia                     Spain
# 3961           Segovia       Castile and Leon                     Spain
# 3962       Zamora city       Castile and Leon                     Spain
#
#       AirQuality  WaterPollution
# 0      46.816038       49.504950
# 1      66.129032       49.107143
# ...

# %%
df['Country'][3]
# Out:
# 'Germany'

# %%
df[df['Country'] == 'Germany']
# Out:
#                         City                   Region  Country  AirQuality  \
# 3                     Berlin                           Germany   62.364130
# 28                   Cologne   North Rhine-Westphalia  Germany   60.714286
# 40                      Bonn   North Rhine-Westphalia  Germany   82.812500
# 52                 Heilbronn        Baden-Wurttemberg  Germany   80.000000
# 76                    Aachen   North Rhine-Westphalia  Germany   70.454545
# ...                      ...                      ...      ...         ...
# 2693             Bad Waldsee        Baden-Wurttemberg  Germany  100.000000
# 2714  Weilheim in Oberbayern                  Bavaria  Germany  100.000000
# 2727                  Buckow              Brandenburg  Germany   87.500000
# 3942                  Erfurt                Thuringia  Germany   85.000000
# 3943  Garmisch-Partenkirchen                  Bavaria  Germany  100.000000
#
#       WaterPollution
# 3          28.612717
# 28         27.777778
# ...

# %%
df[df['Country'] == 'Uzbekistan']
# Out:
#         City Region     Country  AirQuality  WaterPollution
# 21  Tashkent         Uzbekistan   56.451613       49.166667

# %%
df
# Out:
#                   City                 Region                   Country  \
# 0        New York City               New York  United States of America
# 1     Washington, D.C.   District of Columbia  United States of America
# 2        San Francisco             California  United States of America
# 3               Berlin                                          Germany
# 4          Los Angeles             California  United States of America
# ...                ...                    ...                       ...
# 3958             Yanbu        Medina Province              Saudi Arabia
# 3959           Cordoba              Andalusia                     Spain
# 3960               Vic              Catalonia                     Spain
# 3961           Segovia       Castile and Leon                     Spain
# 3962       Zamora city       Castile and Leon                     Spain
#
#       AirQuality  WaterPollution
# 0      46.816038       49.504950
# 1      66.129032       49.107143
# ...

# %%
df1=pd.pivot_table(df, index=['Country','City'])
df1
# Out:
# <ipython-input-26-bc2ba912f670>:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   df1=pd.pivot_table(df, index=['Country','City'])
#                       AirQuality  WaterPollution
# Country     City
# Afghanistan Andkhoy    50.000000       50.000000
#             Farah     100.000000        0.000000
#             Herat      43.750000       31.250000
#             Kabul      18.421053       81.060606
#             Kandahar    0.000000       75.000000
# ...                          ...             ...
# Zambia      Mansa      75.000000       25.000000
# Zimbabwe    Bindura    50.000000       75.000000
#             Bulawayo   67.857143       71.428571
#             Harare     38.461538       87.500000
#             Masvingo   25.000000       62.500000
#
# [3895 rows x 2 columns]

# %%
df1.loc[['Uzbekistan','Germany']]
# Out:
#                           AirQuality  WaterPollution
# Country    City
# Uzbekistan Tashkent        56.451613       49.166667
# Germany    Aachen          70.454545       17.857143
#            Aalen           87.500000       50.000000
#            Abensberg      100.000000       50.000000
#            Amberg         100.000000       50.000000
# ...                              ...             ...
#            Wilhelmshaven  100.000000       50.000000
#            Wolfsburg       96.875000        0.000000
#            Worms           60.000000      100.000000
#            Wuppertal       90.000000        0.000000
#            Zwickau         75.000000       50.000000
#
# [125 rows x 2 columns]

# %%
df2 = df1.copy()
df2
# Out:
#                       AirQuality  WaterPollution
# Country     City
# Afghanistan Andkhoy    50.000000       50.000000
#             Farah     100.000000        0.000000
#             Herat      43.750000       31.250000
#             Kabul      18.421053       81.060606
#             Kandahar    0.000000       75.000000
# ...                          ...             ...
# Zambia      Mansa      75.000000       25.000000
# Zimbabwe    Bindura    50.000000       75.000000
#             Bulawayo   67.857143       71.428571
#             Harare     38.461538       87.500000
#             Masvingo   25.000000       62.500000
#
# [3895 rows x 2 columns]

# %%
df2['AirPollution']=100-df2['AirQuality']
df2
# Out:
#                       AirQuality  WaterPollution  AirPollution
# Country     City
# Afghanistan Andkhoy    50.000000       50.000000     50.000000
#             Farah     100.000000        0.000000      0.000000
#             Herat      43.750000       31.250000     56.250000
#             Kabul      18.421053       81.060606     81.578947
#             Kandahar    0.000000       75.000000    100.000000
# ...                          ...             ...           ...
# Zambia      Mansa      75.000000       25.000000     25.000000
# Zimbabwe    Bindura    50.000000       75.000000     50.000000
#             Bulawayo   67.857143       71.428571     32.142857
#             Harare     38.461538       87.500000     61.538462
#             Masvingo   25.000000       62.500000     75.000000
#
# [3895 rows x 3 columns]

# %%
df2['WaterQuality']=100-df2['WaterPollution']
df2
# Out:
#                       AirQuality  WaterPollution  AirPollution  WaterQuality
# Country     City
# Afghanistan Andkhoy    50.000000       50.000000     50.000000     50.000000
#             Farah     100.000000        0.000000      0.000000    100.000000
#             Herat      43.750000       31.250000     56.250000     68.750000
#             Kabul      18.421053       81.060606     81.578947     18.939394
#             Kandahar    0.000000       75.000000    100.000000     25.000000
# ...                          ...             ...           ...           ...
# Zambia      Mansa      75.000000       25.000000     25.000000     75.000000
# Zimbabwe    Bindura    50.000000       75.000000     50.000000     25.000000
#             Bulawayo   67.857143       71.428571     32.142857     28.571429
#             Harare     38.461538       87.500000     61.538462     12.500000
#             Masvingo   25.000000       62.500000     75.000000     37.500000
#
# [3895 rows x 4 columns]

# %%
df3 = pd.DataFrame(df2.value_counts, index = df2.index, columns=[['AIR','AIR','WATER','WATER'],['AirQuality','AirPollution','WaterPollution','WaterQuality']])
df3
# Out:
#                                                                     AIR  \
#                                                              AirQuality
# Country     City
# Afghanistan Andkhoy   <bound method DataFrame.value_counts of       ...
#             Farah     <bound method DataFrame.value_counts of       ...
#             Herat     <bound method DataFrame.value_counts of       ...
#             Kabul     <bound method DataFrame.value_counts of       ...
#             Kandahar  <bound method DataFrame.value_counts of       ...
# ...                                                                 ...
# Zambia      Mansa     <bound method DataFrame.value_counts of       ...
# Zimbabwe    Bindura   <bound method DataFrame.value_counts of       ...
#             Bulawayo  <bound method DataFrame.value_counts of       ...
#             Harare    <bound method DataFrame.value_counts of       ...
#             Masvingo  <bound method DataFrame.value_counts of       ...
#
# ...

# %%
df3['AIR']
# Out:
#                                                              AirQuality  \
# Country     City
# Afghanistan Andkhoy   <bound method DataFrame.value_counts of       ...
#             Farah     <bound method DataFrame.value_counts of       ...
#             Herat     <bound method DataFrame.value_counts of       ...
#             Kabul     <bound method DataFrame.value_counts of       ...
#             Kandahar  <bound method DataFrame.value_counts of       ...
# ...                                                                 ...
# Zambia      Mansa     <bound method DataFrame.value_counts of       ...
# Zimbabwe    Bindura   <bound method DataFrame.value_counts of       ...
#             Bulawayo  <bound method DataFrame.value_counts of       ...
#             Harare    <bound method DataFrame.value_counts of       ...
#             Masvingo  <bound method DataFrame.value_counts of       ...
#
#                                                            AirPollution
# ...

# %%
df3
# Out:
#                                                                     AIR  \
#                                                              AirQuality
# Country     City
# Afghanistan Andkhoy   <bound method DataFrame.value_counts of       ...
#             Farah     <bound method DataFrame.value_counts of       ...
#             Herat     <bound method DataFrame.value_counts of       ...
#             Kabul     <bound method DataFrame.value_counts of       ...
#             Kandahar  <bound method DataFrame.value_counts of       ...
# ...                                                                 ...
# Zambia      Mansa     <bound method DataFrame.value_counts of       ...
# Zimbabwe    Bindura   <bound method DataFrame.value_counts of       ...
#             Bulawayo  <bound method DataFrame.value_counts of       ...
#             Harare    <bound method DataFrame.value_counts of       ...
#             Masvingo  <bound method DataFrame.value_counts of       ...
#
# ...

# %%
df3.columns.names = ['Object', 'Info']
df3
# Out:
# Object                                                              AIR  \
# Info                                                         AirQuality
# Country     City
# Afghanistan Andkhoy   <bound method DataFrame.value_counts of       ...
#             Farah     <bound method DataFrame.value_counts of       ...
#             Herat     <bound method DataFrame.value_counts of       ...
#             Kabul     <bound method DataFrame.value_counts of       ...
#             Kandahar  <bound method DataFrame.value_counts of       ...
# ...                                                                 ...
# Zambia      Mansa     <bound method DataFrame.value_counts of       ...
# Zimbabwe    Bindura   <bound method DataFrame.value_counts of       ...
#             Bulawayo  <bound method DataFrame.value_counts of       ...
#             Harare    <bound method DataFrame.value_counts of       ...
#             Masvingo  <bound method DataFrame.value_counts of       ...
#
# ...

# %%
df3.index.names
# Out:
# FrozenList(['Country', 'City'])

# %%
df3
# Out:
# Object                                                              AIR  \
# Info                                                         AirQuality
# Country     City
# Afghanistan Andkhoy   <bound method DataFrame.value_counts of       ...
#             Farah     <bound method DataFrame.value_counts of       ...
#             Herat     <bound method DataFrame.value_counts of       ...
#             Kabul     <bound method DataFrame.value_counts of       ...
#             Kandahar  <bound method DataFrame.value_counts of       ...
# ...                                                                 ...
# Zambia      Mansa     <bound method DataFrame.value_counts of       ...
# Zimbabwe    Bindura   <bound method DataFrame.value_counts of       ...
#             Bulawayo  <bound method DataFrame.value_counts of       ...
#             Harare    <bound method DataFrame.value_counts of       ...
#             Masvingo  <bound method DataFrame.value_counts of       ...
#
# ...

# %%
df3.swaplevel('Country', 'City')
# Out:
# Object                                                              AIR  \
# Info                                                         AirQuality
# City     Country
# Andkhoy  Afghanistan  <bound method DataFrame.value_counts of       ...
# Farah    Afghanistan  <bound method DataFrame.value_counts of       ...
# Herat    Afghanistan  <bound method DataFrame.value_counts of       ...
# Kabul    Afghanistan  <bound method DataFrame.value_counts of       ...
# Kandahar Afghanistan  <bound method DataFrame.value_counts of       ...
# ...                                                                 ...
# Mansa    Zambia       <bound method DataFrame.value_counts of       ...
# Bindura  Zimbabwe     <bound method DataFrame.value_counts of       ...
# Bulawayo Zimbabwe     <bound method DataFrame.value_counts of       ...
# Harare   Zimbabwe     <bound method DataFrame.value_counts of       ...
# Masvingo Zimbabwe     <bound method DataFrame.value_counts of       ...
#
# ...

# %%
df3.sort_index(level=0, ascending=False)
# Out:
# Object                                                              AIR  \
# Info                                                         AirQuality
# Country     City
# Zimbabwe    Masvingo  <bound method DataFrame.value_counts of       ...
#             Harare    <bound method DataFrame.value_counts of       ...
#             Bulawayo  <bound method DataFrame.value_counts of       ...
#             Bindura   <bound method DataFrame.value_counts of       ...
# Zambia      Mansa     <bound method DataFrame.value_counts of       ...
# ...                                                                 ...
# Afghanistan Kandahar  <bound method DataFrame.value_counts of       ...
#             Kabul     <bound method DataFrame.value_counts of       ...
#             Herat     <bound method DataFrame.value_counts of       ...
#             Farah     <bound method DataFrame.value_counts of       ...
#             Andkhoy   <bound method DataFrame.value_counts of       ...
#
# ...
