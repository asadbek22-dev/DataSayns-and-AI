# %%
import pandas as pd

# %%
import numpy as np

# %%
from pandas import Series#Malumotlar tuzilmasi

# %%
a=Series([4,5,6,7,8,9.3,-10])

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
a
# Out:
# 0     4.0
# 1     5.0
# 2     6.0
# 3     7.0
# 4     8.0
# 5     9.3
# 6   -10.0
# dtype: float64

# %%
a.values
# Out:
# array([  4. ,   5. ,   6. ,   7. ,   8. ,   9.3, -10. ])

# %%
a.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
a[0]
# Out:
# 4.0

# %%
a2=Series([1,2,6,9],index=['a','b','c','d'])

# %%
a2
# Out:
# a    1
# b    2
# c    6
# d    9
# dtype: int64

# %%
a2.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
a2['a']
# Out:
# 1

# %%
a2[['a','c','d']]
# Out:
# a    1
# c    6
# d    9
# dtype: int64

# %%
a2[['d','d','d']]
# Out:
# d    9
# d    9
# d    9
# dtype: int64

# %%
a2[a2>2]
# Out:
# c    6
# d    9
# dtype: int64

# %%
a2[a2<3]
# Out:
# a    1
# b    2
# dtype: int64

# %%
a2*2
# Out:
# a     2
# b     4
# c    12
# d    18
# dtype: int64

# %%
a2
# Out:
# a    1
# b    2
# c    6
# d    9
# dtype: int64

# %%
np.exp(a2)
# Out:
# a       2.718282
# b       7.389056
# c     403.428793
# d    8103.083928
# dtype: float64

# %%
a2['a']
# Out:
# 1

# %%
a2
# Out:
# a    1
# b    2
# c    6
# d    9
# dtype: int64

# %%
car = {'Malibu':40000,'Lacetti':20000,'Toyota':45000,'Mazda':52000,'Honda':38000}

# %%
type(car)
# Out:
# dict

# %%
car1=Series(car)

# %%
type(car1)
# Out:
# pandas.core.series.Series

# %%
car1
# Out:
# Malibu     40000
# Lacetti    20000
# Toyota     45000
# Mazda      52000
# Honda      38000
# dtype: int64

# %%
car1=Series({'Malibu':40000,'Lacetti':20000,'Toyota':45000,'Mazda':52000,'Honda':38000})

# %%
car1
# Out:
# Malibu     40000
# Lacetti    20000
# Toyota     45000
# Mazda      52000
# Honda      38000
# dtype: int64

# %%
'Malibu' in car1
# Out:
# True

# %%
'BMW' in car1
# Out:
# False

# %%
car1['Toyota']
# Out:
# 45000

# %%
car
# Out:
# {'Malibu': 40000,
#  'Lacetti': 20000,
#  'Toyota': 45000,
#  'Mazda': 52000,
#  'Honda': 38000}

# %%
models = ['Toyota','Malibu','Jaguar','Honda','Lacetti','Mazda','BMW','MERCEDES']

# %%
cars2 = Series(car,index=models)

# %%
cars2
# Out:
# Toyota      45000.0
# Malibu      40000.0
# Jaguar          NaN
# Honda       38000.0
# Lacetti     20000.0
# Mazda       52000.0
# BMW             NaN
# MERCEDES        NaN
# dtype: float64

# %%
cars2.isnull()
# Out:
# Toyota      False
# Malibu      False
# Jaguar       True
# Honda       False
# Lacetti     False
# Mazda       False
# BMW          True
# MERCEDES     True
# dtype: bool

# %%
cars2.notnull()
# Out:
# Toyota       True
# Malibu       True
# Jaguar      False
# Honda        True
# Lacetti      True
# Mazda        True
# BMW         False
# MERCEDES    False
# dtype: bool

# %%
cars2
# Out:
# Toyota      45000.0
# Malibu      40000.0
# Jaguar          NaN
# Honda       38000.0
# Lacetti     20000.0
# Mazda       52000.0
# BMW             NaN
# MERCEDES        NaN
# dtype: float64

# %%
car1
# Out:
# Malibu     40000
# Lacetti    20000
# Toyota     45000
# Mazda      52000
# Honda      38000
# dtype: int64

# %%
car1+cars2
# Out:
# BMW              NaN
# Honda        76000.0
# Jaguar           NaN
# Lacetti      40000.0
# MERCEDES         NaN
# Malibu       80000.0
# Mazda       104000.0
# Toyota       90000.0
# dtype: float64

# %%
cars2.name='Avtosololon'

# %%
cars2.index.name='Modellar'

# %%
cars2
# Out:
# Modellar
# Toyota      45000.0
# Malibu      40000.0
# Jaguar          NaN
# Honda       38000.0
# Lacetti     20000.0
# Mazda       52000.0
# BMW             NaN
# MERCEDES        NaN
# Name: Avtosololon, dtype: float64
