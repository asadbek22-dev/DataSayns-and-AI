# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.random.randn(3,4),index=list('abc'), columns=['Olma','Anor','Qovun','Anjir'])
df
# Out:
#        Olma      Anor     Qovun     Anjir
# a -0.821735 -0.297353  2.206452  1.171698
# b -1.187799  0.933740  1.751790 -1.484143
# c -0.044383 -0.152441  0.520070 -0.208792

# %%
np.abs(df)
# Out:
#        Olma      Anor     Qovun     Anjir
# a  0.821735  0.297353  2.206452  1.171698
# b  1.187799  0.933740  1.751790  1.484143
# c  0.044383  0.152441  0.520070  0.208792

# %%
np.round(df)
# Out:
#    Olma  Anor  Qovun  Anjir
# a  -1.0  -0.0    2.0    1.0
# b  -1.0   1.0    2.0   -1.0
# c  -0.0  -0.0    1.0   -0.0

# %%
df.mean()
# Out:
# Olma    -0.684639
# Anor     0.161316
# Qovun    1.492771
# Anjir   -0.173746
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# a    0.564766
# b    0.003397
# c    0.028614
# dtype: float64

# %%
df.apply(np.abs)
# Out:
#        Olma      Anor     Qovun     Anjir
# a  0.821735  0.297353  2.206452  1.171698
# b  1.187799  0.933740  1.751790  1.484143
# c  0.044383  0.152441  0.520070  0.208792

# %%
df.apply(sum , axis=1)
# Out:
# a    2.259062
# b    0.013588
# c    0.114455
# dtype: float64

# %%
f=lambda x:x.max()-x.min()

# %%
df.apply(lambda x:x.max()-x.min())
# Out:
# Olma     1.143416
# Anor     1.231093
# Qovun    1.686382
# Anjir    2.655841
# dtype: float64

# %%
def foo(x):
    return pd.Series([x.min(), x.max()], index=['min', 'max'])

# %%
df.apply(foo)
# Out:
#          Olma      Anor     Qovun     Anjir
# min -1.187799 -0.297353  0.520070 -1.484143
# max -0.044383  0.933740  2.206452  1.171698

# %%
df = pd.DataFrame(np.arange(1,13).reshape(3,4), index=list('abc'), columns=['Olma','Anor','Qovun','Anjir'])
df
# Out:
#    Olma  Anor  Qovun  Anjir
# a     1     2      3      4
# b     5     6      7      8
# c     9    10     11     12

# %%
df.applymap(lambda x: x*x)
# Out:
#    Olma  Anor  Qovun  Anjir
# a     1     4      9     16
# b    25    36     49     64
# c    81   100    121    144
