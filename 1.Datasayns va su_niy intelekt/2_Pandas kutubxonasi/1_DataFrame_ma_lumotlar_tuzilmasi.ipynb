# %%
import pandas as pd

# %%
data={
    'Yili' : [ 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2010],
    'Aholi soni' : [ 33.9, 33.5, 32.9, 32.5, 31.9, 31.4, 30.9, 28.5],
    'Temp' : [ 1.54, 1.48, 1.56, 1.62, 1.65, 1.66, 1.64, 1.53]
}
df=pd.DataFrame(data)

# %%
df
# Out:
#    Yili  Aholi soni  Temp
# 0  2021        33.9  1.54
# 1  2020        33.5  1.48
# 2  2019        32.9  1.56
# 3  2018        32.5  1.62
# 4  2017        31.9  1.65
# 5  2016        31.4  1.66
# 6  2015        30.9  1.64
# 7  2010        28.5  1.53

# %%
df.head()
# Out:
#    Yili  Aholi soni  Temp
# 0  2021        33.9  1.54
# 1  2020        33.5  1.48
# 2  2019        32.9  1.56
# 3  2018        32.5  1.62
# 4  2017        31.9  1.65

# %%
df=pd.DataFrame(data,columns=['Yili','Temp','Aholi soni'])

# %%
df
# Out:
#    Yili  Temp  Aholi soni
# 0  2021  1.54        33.9
# 1  2020  1.48        33.5
# 2  2019  1.56        32.9
# 3  2018  1.62        32.5
# 4  2017  1.65        31.9
# 5  2016  1.66        31.4
# 6  2015  1.64        30.9
# 7  2010  1.53        28.5

# %%
df=pd.DataFrame(data,columns=['Yili','Temp','Aholi soni','YAIM'])

# %%
df
# Out:
#    Yili  Temp  Aholi soni YAIM
# 0  2021  1.54        33.9  NaN
# 1  2020  1.48        33.5  NaN
# 2  2019  1.56        32.9  NaN
# 3  2018  1.62        32.5  NaN
# 4  2017  1.65        31.9  NaN
# 5  2016  1.66        31.4  NaN
# 6  2015  1.64        30.9  NaN
# 7  2010  1.53        28.5  NaN

# %%
df=pd.DataFrame(data,columns=['Yili','Temp','Aholi soni','YAIM'],index=[21,20,19,18,17,16,15,10])

# %%
df
# Out:
#     Yili  Temp  Aholi soni YAIM
# 21  2021  1.54        33.9  NaN
# 20  2020  1.48        33.5  NaN
# 19  2019  1.56        32.9  NaN
# 18  2018  1.62        32.5  NaN
# 17  2017  1.65        31.9  NaN
# 16  2016  1.66        31.4  NaN
# 15  2015  1.64        30.9  NaN
# 10  2010  1.53        28.5  NaN

# %%
aholi=df['Aholi soni']

# %%
aholi
# Out:
# 21    33.9
# 20    33.5
# 19    32.9
# 18    32.5
# 17    31.9
# 16    31.4
# 15    30.9
# 10    28.5
# Name: Aholi soni, dtype: float64

# %%
type(aholi)
# Out:
# pandas.core.series.Series

# %%
df.Temp
# Out:
# 21    1.54
# 20    1.48
# 19    1.56
# 18    1.62
# 17    1.65
# 16    1.66
# 15    1.64
# 10    1.53
# Name: Temp, dtype: float64

# %%
df
# Out:
#     Yili  Temp  Aholi soni YAIM
# 21  2021  1.54        33.9  NaN
# 20  2020  1.48        33.5  NaN
# 19  2019  1.56        32.9  NaN
# 18  2018  1.62        32.5  NaN
# 17  2017  1.65        31.9  NaN
# 16  2016  1.66        31.4  NaN
# 15  2015  1.64        30.9  NaN
# 10  2010  1.53        28.5  NaN

# %%
df.YAIM=0

# %%
df
# Out:
#     Yili  Temp  Aholi soni  YAIM
# 21  2021  1.54        33.9     0
# 20  2020  1.48        33.5     0
# 19  2019  1.56        32.9     0
# 18  2018  1.62        32.5     0
# 17  2017  1.65        31.9     0
# 16  2016  1.66        31.4     0
# 15  2015  1.64        30.9     0
# 10  2010  1.53        28.5     0

# %%
val=pd.Series([1700,1650,1300],index=[21,20,10])
df.YAIM=val

# %%
df
# Out:
#     Yili  Temp  Aholi soni    YAIM
# 21  2021  1.54        33.9  1700.0
# 20  2020  1.48        33.5  1650.0
# 19  2019  1.56        32.9     NaN
# 18  2018  1.62        32.5     NaN
# 17  2017  1.65        31.9     NaN
# 16  2016  1.66        31.4     NaN
# 15  2015  1.64        30.9     NaN
# 10  2010  1.53        28.5  1300.0

# %%
val = [1700, 1670, 1600, 1590, 1400, 1300, 1350, 1360]
df['YAIM']=val

# %%
df
# Out:
#     Yili  Temp  Aholi soni  YAIM
# 21  2021  1.54        33.9  1700
# 20  2020  1.48        33.5  1670
# 19  2019  1.56        32.9  1600
# 18  2018  1.62        32.5  1590
# 17  2017  1.65        31.9  1400
# 16  2016  1.66        31.4  1300
# 15  2015  1.64        30.9  1350
# 10  2010  1.53        28.5  1360

# %%
df['1500+']=df.YAIM>1500

# %%
df
# Out:
#     Yili  Temp  Aholi soni  YAIM  1500+
# 21  2021  1.54        33.9  1700   True
# 20  2020  1.48        33.5  1670   True
# 19  2019  1.56        32.9  1600   True
# 18  2018  1.62        32.5  1590   True
# 17  2017  1.65        31.9  1400  False
# 16  2016  1.66        31.4  1300  False
# 15  2015  1.64        30.9  1350  False
# 10  2010  1.53        28.5  1360  False

# %%
del df['1500+']

# %%
df
# Out:
#     Yili  Temp  Aholi soni  YAIM
# 21  2021  1.54        33.9  1700
# 20  2020  1.48        33.5  1670
# 19  2019  1.56        32.9  1600
# 18  2018  1.62        32.5  1590
# 17  2017  1.65        31.9  1400
# 16  2016  1.66        31.4  1300
# 15  2015  1.64        30.9  1350
# 10  2010  1.53        28.5  1360

# %%
data={
    'Uzbekistan':{2021:33.9, 2020:33.5, 2019:32.9, 2018:32.5, 2017:31.9},
    'Kazakhstan':{2021:18.9, 2020:18.7, 2019:18.5, 2018:18.3, 2017:18.1, 2016:17.8}
}
df2 = pd.DataFrame(data)

# %%
df2
# Out:
#       Uzbekistan  Kazakhstan
# 2021        33.9        18.9
# 2020        33.5        18.7
# 2019        32.9        18.5
# 2018        32.5        18.3
# 2017        31.9        18.1
# 2016         NaN        17.8

# %%
df2.index.name='Yil'

# %%
df2
# Out:
#       Uzbekistan  Kazakhstan
# Yil
# 2021        33.9        18.9
# 2020        33.5        18.7
# 2019        32.9        18.5
# 2018        32.5        18.3
# 2017        31.9        18.1
# 2016         NaN        17.8

# %%
df2 = pd.DataFrame(data,index=[2021, 2019, 2017])

# %%
df2
# Out:
#       Uzbekistan  Kazakhstan
# 2021        33.9        18.9
# 2019        32.9        18.5
# 2017        31.9        18.1

# %%
df2
# Out:
#       Uzbekistan  Kazakhstan
# 2021        33.9        18.9
# 2019        32.9        18.5
# 2017        31.9        18.1

# %%
df.index
# Out:
# Int64Index([21, 20, 19, 18, 17, 16, 15, 10], dtype='int64')

# %%
df.columns
# Out:
# Index(['Yili', 'Temp', 'Aholi soni', 'YAIM'], dtype='object')

# %%
indeks=df.columns

# %%
indeks
# Out:
# Index(['Yili', 'Temp', 'Aholi soni', 'YAIM'], dtype='object')

# %%
df
# Out:
#     Yili  Temp  Aholi soni  YAIM
# 21  2021  1.54        33.9  1700
# 20  2020  1.48        33.5  1670
# 19  2019  1.56        32.9  1600
# 18  2018  1.62        32.5  1590
# 17  2017  1.65        31.9  1400
# 16  2016  1.66        31.4  1300
# 15  2015  1.64        30.9  1350
# 10  2010  1.53        28.5  1360

# %%
'Temp' in indeks
# Out:
# True

# %%
df2
# Out:
#       Uzbekistan  Kazakhstan
# 2021        33.9        18.9
# 2019        32.9        18.5
# 2017        31.9        18.1

# %%
'Tajikistan' in df2.columns
# Out:
# False

# %%
2021 in df2.index
# Out:
# True

# %%
indeks
# Out:
# Index(['Yili', 'Temp', 'Aholi soni', 'YAIM'], dtype='object')

# %%
indeks[0]
# Out:
# 'Yili'

# %%
indeks[2:4]
# Out:
# Index(['Aholi soni', 'YAIM'], dtype='object')

# %%
df
# Out:
#     Yili  Temp  Aholi soni  YAIM
# 21  2021  1.54        33.9  1700
# 20  2020  1.48        33.5  1670
# 19  2019  1.56        32.9  1600
# 18  2018  1.62        32.5  1590
# 17  2017  1.65        31.9  1400
# 16  2016  1.66        31.4  1300
# 15  2015  1.64        30.9  1350
# 10  2010  1.53        28.5  1360

# %%
indeks[0]="qiymat"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-190-5367846f781e> in <cell line: 1>()
# ----> 1 indeks[0]="qiymat"
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in __setitem__(self, key, value)
#    5300     @final
#    5301     def __setitem__(self, key, value):
# -> 5302         raise TypeError("Index does not support mutable operations")
#    5303
#    5304     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %%
data={
    'Uzbekistan':{2021:33.9, 2020:33.5, 2019:32.9, 2018:32.5, 2017:31.9},
    'Kazakhstan':{2021:18.9, 2020:18.7, 2019:18.5, 2018:18.3, 2017:18.1, 2016:17.8}
}
df = pd.DataFrame(data)

# %%
df
# Out:
#       Uzbekistan  Kazakhstan
# 2021        33.9        18.9
# 2020        33.5        18.7
# 2019        32.9        18.5
# 2018        32.5        18.3
# 2017        31.9        18.1
# 2016         NaN        17.8

# %%
user= {"anvar":"anvarbek223", "olim":"olimtoy", "maryam":"maryam334455", "javohir":"javohir445"}
emails= {"anvar":"anvar@gmail.com", "olim":"olim@gmail.com", "maryam":"maryam@gmail.com", "javohir":"javohir445@gmail.com"}

data={
    'user':user,
    'email':emails
}
df= pd.DataFrame(data)

# %%
df
# Out:
#                  user                 email
# anvar     anvarbek223       anvar@gmail.com
# olim          olimtoy        olim@gmail.com
# maryam   maryam334455      maryam@gmail.com
# javohir    javohir445  javohir445@gmail.com

# %%
df.index
# Out:
# Index(['anvar', 'olim', 'maryam', 'javohir'], dtype='object')

# %%
arr =['anvar', 'olim', 'maryam', 'javohir']

# %%
arr[0]
# Out:
# 'anvar'

# %%
arr[1]
# Out:
# 'olim'

# %%
data2={
    'user':{"olim":"olimjon21", "maryam":"maryam2020"},
    'email':{ "olim":"olimjon21@gmail.com", "maryam":"maryam20@gmail.com",}
}

# %%
df2=df.append(pd.DataFrame(data2))
df2
# Out:
# <ipython-input-10-ddc55e8be190>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2=df.append(pd.DataFrame(data2))
#                  user                 email
# anvar     anvarbek223       anvar@gmail.com
# olim          olimtoy        olim@gmail.com
# maryam   maryam334455      maryam@gmail.com
# javohir    javohir445  javohir445@gmail.com
# olim        olimjon21   olimjon21@gmail.com
# maryam     maryam2020    maryam20@gmail.com

# %%
new=pd.Index(['olim','nafisa','hamida'])
new
# Out:
# Index(['olim', 'nafisa', 'hamida'], dtype='object')

# %%
new.isin(df2.index)
# Out:
# array([ True, False, False])

# %%
df2.index.difference(new)
# Out:
# Index(['anvar', 'javohir', 'maryam'], dtype='object')

# %%
new.difference(df2.index)
# Out:
# Index(['hamida', 'nafisa'], dtype='object')

# %%
df2.index.union(new)
# Out:
# Index(['anvar', 'hamida', 'javohir', 'maryam', 'maryam', 'nafisa', 'olim',
#        'olim'],
#       dtype='object')

# %%
df2.index.delete(0)
# Out:
# Index(['olim', 'maryam', 'javohir', 'olim', 'maryam'], dtype='object')

# %%
new.drop('hamida')
# Out:
# Index(['olim', 'nafisa'], dtype='object')
